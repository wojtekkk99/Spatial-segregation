# %%
from district import District
from city import City
from schelling import Schelling
from gaylord import Gaylord
from visualization import Visualization
import matplotlib.pyplot as plt
import imageio
from os import listdir

# %%
district = District()
print(f'Population features: \nrases: {district.rases} \nmaterial status: {district.salaries}')
# Out:
# Population features:
# rases: ['white', 'black']
# material status: ['rich', 'poor']

# %% [markdown]
# ### Segregation using Schelling model

# %% [markdown]
# #### Testing agents_ratio parameter (0.6, 0.7, 0.5) on simulation of the algorithm

# %%
city = City(district, size=80, agents_ratio=0.6)
schelling = Schelling(city, district, a=4, n_steps=8000)

visualization = Visualization(schelling)
visualization.show_results()
# Out:
# step: 0, mean si: 1.177720207253886
# step: 2000, mean si: 1.2441069620630099
# step: 4000, mean si: 1.6874847350338582
# step: 6000, mean si: 2.511680523021638
# c:\Users\olasz\Documents\me\informatyka systemów złożonych\Spatial-segregation1\visualization.py:34: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or axes decorations smaller.
#   plt.savefig(f'schelling_{self.agents_ratio}_{self.n_steps}.png')
# c:\Users\olasz\.conda\envs\visearch\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or axes decorations smaller.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
city = City(district, size=80, agents_ratio=0.7)
schelling = Schelling(city, district, a=4, n_steps=8000)

visualization = Visualization(schelling)
visualization.show_results()
# Out:
# step: 0, mean si: 1.4213445751053917
# step: 2000, mean si: 1.709135004275098
# step: 4000, mean si: 2.5899250725370577
# step: 6000, mean si: 3.7636712940417776

# %%
city = City(district, size=80, agents_ratio=0.5)
schelling = Schelling(city, district, a=4, n_steps=8000)

visualization = Visualization(schelling)
visualization.show_results()
# Out:
# step: 0, mean si: 0.9943960149439601
# step: 2000, mean si: 0.940163168726969
# step: 4000, mean si: 1.0262930842631808
# step: 6000, mean si: 1.2101306071238023

# %% [markdown]
# ### Segregation using Gaylord D'Andria model

# %% [markdown]
# #### Testing agents_ratio parameter (0.4, 0.5, 0.6, 0.7) on simulation of the algorithm

# %%
city = City(district, size=80, agents_ratio=0.4)
gaylord = Gaylord(city, district, a=3)

visualization = Visualization(gaylord)
visualization.show_results()
# Out:
# c:\Users\Ola\Desktop\PRZEDMIOTY\informatyka systemów złożonych\Spatial-segregation\visualization.py:34: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or axes decorations smaller.
#   plt.savefig(f'visualizations/{self.algorithm.name}_{self.agents_ratio}_{self.algorithm.n_steps}.png')
# c:\Users\Ola\.conda\envs\nlp\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or axes decorations smaller.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
city = City(district, size=80, agents_ratio=0.5)
gaylord = Gaylord(city, district, a=3)

visualization = Visualization(gaylord)
visualization.show_results()

# %%
city = City(district, size=80, agents_ratio=0.6)
gaylord = Gaylord(city, district, a=3)

visualization = Visualization(gaylord)
visualization.show_results()

# %%
city = City(district, size=80, agents_ratio=0.7)
gaylord = Gaylord(city, district, a=3)

visualization = Visualization(gaylord)
visualization.show_results()

# %% [markdown]
# #### Changed to only two population

# %%
salaries: list[str] = ['rich']
district = District(salaries=salaries)
print(f'Population features: \nrases: {district.rases} \nmaterial status: {district.salaries}')
# Out:
# Population features:
# rases: ['white', 'black']
# material status: ['rich']

# %%
city = City(district, size=80, agents_ratio=0.5)
gaylord = Gaylord(city, district, a=4)

visualization = Visualization(gaylord)
visualization.show_results()

# %%
city = City(district, size=80, agents_ratio=0.6)
gaylord = Gaylord(city, district, a=4)

visualization = Visualization(gaylord)
visualization.show_results()
