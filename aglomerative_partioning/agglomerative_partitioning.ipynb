# %%
import numpy as np
from matplotlib import pyplot as plt
from dataclasses import dataclass, asdict, field
from itertools import count
import random, itertools, statistics

# %%
class Board:
    PERCENTAGE_ATTRIBUTES = ['white', 'latino', 'black', 'white_salary', 'latino_salary', 'black_salary', 'children', 'pets']
    POPULATION = ['population']
    
    def __init__(self, board_size) -> None:
        self.board = self.generate_board(board_size)
        self.groups = {}

    @staticmethod
    def generate_board(board_size):
        return np.matrix([[District() for _ in range(board_size)] for _ in range (board_size)])
    
    def get_int_board(self):
        int_board = np.zeros((self.board.shape[0], self.board.shape[1]))
        for i, j in itertools.product(range(self.board.shape[0]), range(self.board.shape[1])):
            int_board[i, j] = repr(self.board[i, j])
        return int_board
        
    def count_unique(self):
        unique = set()
        for i, j in itertools.product(range(self.board.shape[0]), range(self.board.shape[1])):
            unique.add(self.board[i,j].identifier)
        return len(unique)

    def merge_units(self, u_1xy, u_2xy):
        unit_1_x, unit_1_y = u_1xy
        unit_1 = self.board[unit_1_x, unit_1_y]
        unit_2_x, unit_2_y = u_2xy
        unit_2 = self.board[unit_2_x, unit_2_y]
        
        if unit_1.identifier not in self.groups.keys() and unit_2.identifier not in self.groups.keys():
            group = Group()
            group.add_unit(unit_1)
            group.add_unit(unit_2)
            self.groups[group.identifier] = group
            self.board[unit_1_x, unit_1_y] = group
            self.board[unit_2_x, unit_2_y] = group
        
        if unit_1.identifier in self.groups.keys() and unit_2.identifier not in self.groups.keys():
            self.groups[unit_1.identifier].add_unit(unit_2)
            self.board[unit_2_x, unit_2_y] = self.groups[unit_1.identifier]

        if unit_1.identifier not in self.groups.keys() and unit_2.identifier in self.groups.keys():
            self.groups[unit_2.identifier].add_unit(unit_1)
            self.board[unit_1_x, unit_1_y] = self.groups[unit_2.identifier]
            
            
        if unit_1.identifier in self.groups.keys() and unit_2.identifier in self.groups.keys():
            self.groups[unit_1.identifier].add_unit(unit_2)
            for i, j in itertools.product(range(self.board.shape[0]), range(self.board.shape[1])):
                if self.board[i, j] == unit_2 or self.board[i, j] == unit_1: self.board[i, j] = self.groups[unit_1.identifier]
            del self.groups[unit_2.identifier]
            
    def clusters_raport(self):
        used_ids = []
        
        print("Clusters: ")
        for i, j in itertools.product(range(self.board.shape[0]), range(self.board.shape[1])):
            if self.board[i, j].__class__.__name__ == 'Group' and self.board[i, j].identifier not in used_ids:
                used_ids.append(self.board[i, j].identifier)
                print(f"Amount of units: {len(self.board[i, j].units)}, average cluster information: {str(self.board[i, j])}")
                print(f"Standard deviation: {self.board[i, j].group_standard_deviation()}")
                for unit in self.board[i, j].units:
                    print(f"District data: {str(unit)}")
                print("\n")
                
        print("Single districts: ")
        for i, j in itertools.product(range(self.board.shape[0]), range(self.board.shape[1])):
            if self.board[i, j].__class__.__name__ == 'District' and self.board[i, j].identifier not in used_ids:
                used_ids.append(self.board[i, j].identifier)
                print(f"District data: {str(self.board[i, j])}")
        
    def show_board(self) -> None:
        plt.figure()
        plt.imshow(self.get_int_board(), cmap='gray')
        plt.show()

    @staticmethod
    def bergman_divergence(p, q):
        pd = asdict(p)
        qd = asdict(q)
        result = 0
        for characteristic in Board.PERCENTAGE_ATTRIBUTES:
            result += abs(pd[characteristic] - qd[characteristic])
        return result

    @staticmethod
    def kullback_leibler_divergence(p, q):
        pd = asdict(p)
        qd = asdict(q)
        result = 0
        for characteristic in Board.PERCENTAGE_ATTRIBUTES:
            try:
                result += pd[characteristic] * np.log2(pd[characteristic]/qd[characteristic])
            except ZeroDivisionError:
                ...
        return result
    
    def agglompartition(self, k, divergence_function):
        def neighbours(x, y):
            _min_divergence = np.Inf
            min_x, min_y = 0, 0
            
            for i, j in itertools.product([-1, 0, 1], [-1, 0, 1]):
                if i == 0 and j == 0: continue
                if not (0 <= x+i < self.board.shape[0] and 0 <= y+j < self.board.shape[1]): continue
                if self.board[x, y].identifier == self.board[x+i, y+j].identifier: continue
                divergence = divergence_function(self.board[x, y], self.board[x+i, y+j])
                
                if divergence < _min_divergence:
                    _min_divergence = divergence
                    min_x, min_y = x+i, y+j
                    
            return _min_divergence, min_x, min_y
        
        R_size = self.board.shape[0]
        unique = self.count_unique()
        
        while unique > k:
            min_divergence = np.Inf
            min_x, min_y = np.Inf, np.Inf
            min_x1, min_y1 = np.Inf, np.Inf
            
            for x, y in itertools.product(range(R_size), range(R_size)):
                divergence_min_temp, min_x_temp, min_y_temp = neighbours(x, y)
                if divergence_min_temp < min_divergence:
                    min_divergence = divergence_min_temp
                    min_x, min_y = min_x_temp, min_y_temp
                    min_x1, min_y1 = x, y
                    
            # print(f"""to merge: 
            #       divergence: {min_divergence}
            #       {min_x, min_y}: id {b.board[min_x, min_y].identifier, b.board[min_x, min_y].latino, b.board[min_x, min_y].black, b.board[min_x, min_y].white}
            #       {min_x1, min_y1}: id {b.board[min_x1, min_y1].identifier, b.board[min_x1, min_y1].latino, b.board[min_x1, min_y1].black, b.board[min_x1, min_y1].white}
            #       """)
            # print(b.board, "\n\n")
            
            self.merge_units((min_x, min_y), (min_x1, min_y1))
            unique = self.count_unique()
            
        print(self.clusters_raport())
        print(self.board)
            
        
@dataclass(frozen=False)
class District:
    identifier: int = field(default_factory=count().__next__, init=False, repr=True)
    __min_salary: int = 3010
    __max_salary: int = 6156
    latino: int = field(init=False)
    black: int = field(init=False)
    white: int = field(init=False)
    latino_salary: int = field(init=False)
    black_salary: int = field(init=False)
    white_salary: int = field(init=False)
    children: int = field(init=False)
    pets: int = field(init=False)
    population: int = field(init=False)
    
    def __post_init__(self):
        self.latino = random.randint(0,100)
        self.white = random.randint(0,100-self.latino)
        self.black = 100-self.latino-self.white
        self.latino_salary = int(random.randint(self.__min_salary, self.__max_salary) / self.__max_salary * 100)
        self.black_salary = int(random.randint(self.__min_salary, self.__max_salary) / self.__max_salary * 100)
        self.white_salary = int(random.randint(self.__min_salary, self.__max_salary) / self.__max_salary * 100)
        self.children = random.randint(0, 100)
        self.pets = random.randint(0, 100)
        self.population = random.randint(1000, 10000)
        
    def __repr__(self) -> str:
        return str(self.identifier)
    
    def __str__(self) -> str:
        return f"{self.__class__.__name__} id: {self.identifier}, black: {self.black}%, white: {self.white}%, latino: {self.latino}%, latino salary: {self.latino_salary}%, black salary: {self.black_salary}%, white salary: {self.white_salary}%, pets: {self.pets}%, children: {self.children}% population: {self.population}"
       
@dataclass(frozen=False)
class Group(District):
    def __post_init__(self):
        self.units = []
        self.latino: int = 0
        self.black: int = 0
        self.white: int = 0
        self.latino_salary: int = 0
        self.black_salary: int = 0
        self.white_salary: int = 0
        self.children = int = 0
        self.pets = int = 0
        self.population: int = 0
    
    def add_unit(self, unit):
        if unit.__class__.__name__ == 'District':
            self.units.append(unit)
            self.update_group_info(unit)
        elif unit.__class__.__name__ == "Group":
            self.units.extend(unit.units)
            for unit in unit.units:
               self.update_group_info(unit)
               
    def __str__(self) -> str:
        return super().__str__()
        
    def __repr__(self):
        return super().__repr__()
    
    def update_group_info(self, unit) -> None:
        for characteristic in Board.PERCENTAGE_ATTRIBUTES:
            exec(f"self.{characteristic} = int(((self.{characteristic} * self.population / 100 + unit.{characteristic} * unit.population / 100) / (unit.population + self.population) ) * 100) ")
        self.population += unit.population
        
    def group_standard_deviation(self):
        result = {k: [] for k in Board.PERCENTAGE_ATTRIBUTES}
        for unit in self.units:
            for characteristic in Board.PERCENTAGE_ATTRIBUTES:
                result[characteristic].append(eval(f"unit.{characteristic}"))
        for characteristic in Board.PERCENTAGE_ATTRIBUTES:
            result[characteristic] = statistics.stdev(result[characteristic])
        return result

# %%
b = Board(5)
print(b.board)
b.agglompartition(12, b.bergman_divergence)
# Out:
# [[126 127 128 129 130]
#  [131 132 133 134 135]
#  [136 137 138 139 140]
#  [141 142 143 144 145]
#  [146 147 148 149 150]]
# Clusters:
# Amount of units: 12, average cluster information: Group id: 152, black: 10%, white: 15%, latino: 65%, latino salary: 62%, black salary: 63%, white salary: 66%, pets: 59%, children: 24% population: 66823
# Standard deviation: {'white': 13.534187911516613, 'latino': 12.629930780299294, 'black': 10.762941470198056, 'white_salary': 13.11112181132931, 'latino_salary': 11.735403570806458, 'black_salary': 14.806837077594398, 'children': 17.3438924714323, 'pets': 25.67674929864477}
# District data: District id: 149, black: 0%, white: 36%, latino: 64%, latino salary: 60%, black salary: 83%, white salary: 71%, pets: 78%, children: 27% population: 1994
# District data: District id: 145, black: 4%, white: 22%, latino: 74%, latino salary: 84%, black salary: 69%, white salary: 63%, pets: 71%, children: 32% population: 6852
# District data: District id: 150, black: 14%, white: 21%, latino: 65%, latino salary: 58%, black salary: 49%, white salary: 57%, pets: 71%, children: 6% population: 9844
# District data: District id: 143, black: 8%, white: 45%, latino: 47%, latino salary: 50%, black salary: 54%, white salary: 65%, pets: 39%, children: 31% population: 6045
# District data: District id: 139, black: 21%, white: 22%, latino: 57%, latino salary: 52%, black salary: 76%, white salary: 66%, pets: 7%, children: 25% population: 7335
# District data: District id: 138, black: 2%, white: 11%, latino: 87%, latino salary: 74%, black salary: 53%, white salary: 92%, pets: 56%, children: 17% population: 9614
# District data: District id: 133, black: 31%, white: 4%, latino: 65%, latino salary: 75%, black salary: 53%, white salary: 60%, pets: 45%, children: 25% population: 2125
# District data: District id: 127, black: 7%, white: 15%, latino: 78%, latino salary: 73%, black salary: 98%, white salary: 62%, pets: 80%, children: 36% population: 8602
# District data: District id: 126, black: 27%, white: 17%, latino: 56%, latino salary: 66%, black salary: 65%, white salary: 94%, pets: 79%, children: 27% population: 7176
# District data: District id: 134, black: 11%, white: 8%, latino: 81%, latino salary: 63%, black salary: 79%, white salary: 64%, pets: 99%, children: 68% population: 3129
# District data: District id: 129, black: 11%, white: 2%, latino: 87%, latino salary: 63%, black salary: 61%, white salary: 56%, pets: 91%, children: 53% population: 2584
# District data: District id: 130, black: 29%, white: 0%, latino: 71%, latino salary: 87%, black salary: 74%, white salary: 53%, pets: 49%, children: 8% population: 1523
#
#
# Amount of units: 2, average cluster information: Group id: 153, black: 58%, white: 9%, latino: 32%, latino salary: 94%, black salary: 88%, white salary: 64%, pets: 35%, children: 67% population: 7972
# Standard deviation: {'white': 8.48528137423857, 'latino': 8.48528137423857, 'black': 0.0, 'white_salary': 12.727922061357855, 'latino_salary': 22.627416997969522, 'black_salary': 6.363961030678928, 'children': 4.242640687119285, 'pets': 4.242640687119285}
# District data: District id: 136, black: 58%, white: 20%, latino: 22%, latino salary: 67%, black salary: 96%, white salary: 49%, pets: 41%, children: 62% population: 1115
# District data: District id: 131, black: 58%, white: 8%, latino: 34%, latino salary: 99%, black salary: 87%, white salary: 67%, pets: 35%, children: 68% population: 6857
#
#
# Amount of units: 2, average cluster information: Group id: 156, black: 34%, white: 62%, latino: 2%, latino salary: 75%, black salary: 96%, white salary: 72%, pets: 33%, children: 29% population: 16425
# Standard deviation: {'white': 9.192388155425117, 'latino': 2.8284271247461903, 'black': 12.020815280171307, 'white_salary': 11.313708498984761, 'latino_salary': 9.899494936611665, 'black_salary': 0.7071067811865476, 'children': 42.42640687119285, 'pets': 4.242640687119285}
# District data: District id: 146, black: 42%, white: 57%, latino: 1%, latino salary: 82%, black salary: 96%, white salary: 65%, pets: 31%, children: 2% population: 9028
# District data: District id: 141, black: 25%, white: 70%, latino: 5%, latino salary: 68%, black salary: 97%, white salary: 81%, pets: 37%, children: 62% population: 7397
#
#
# Single districts:
# District data: District id: 128, black: 83%, white: 11%, latino: 6%, latino salary: 76%, black salary: 78%, white salary: 49%, pets: 3%, children: 17% population: 7373
# District data: District id: 132, black: 42%, white: 50%, latino: 8%, latino salary: 76%, black salary: 92%, white salary: 62%, pets: 67%, children: 47% population: 3044
# District data: District id: 135, black: 45%, white: 9%, latino: 46%, latino salary: 53%, black salary: 88%, white salary: 59%, pets: 89%, children: 5% population: 2149
# District data: District id: 137, black: 44%, white: 34%, latino: 22%, latino salary: 81%, black salary: 77%, white salary: 49%, pets: 17%, children: 26% population: 7256
# District data: District id: 140, black: 5%, white: 65%, latino: 30%, latino salary: 80%, black salary: 86%, white salary: 80%, pets: 10%, children: 54% population: 3097
# District data: District id: 142, black: 17%, white: 54%, latino: 29%, latino salary: 68%, black salary: 60%, white salary: 90%, pets: 3%, children: 15% population: 2662
# District data: District id: 144, black: 11%, white: 6%, latino: 83%, latino salary: 68%, black salary: 84%, white salary: 74%, pets: 90%, children: 92% population: 2878
# District data: District id: 147, black: 35%, white: 37%, latino: 28%, latino salary: 54%, black salary: 87%, white salary: 54%, pets: 12%, children: 93% population: 3617
# District data: District id: 148, black: 59%, white: 7%, latino: 34%, latino salary: 98%, black salary: 69%, white salary: 95%, pets: 33%, children: 92% population: 8885
# None
# [[152 152 128 152 152]
#  [153 132 152 152 135]
#  [153 137 152 152 140]
#  [156 142 152 144 152]
#  [156 147 148 152 152]]

# %%
b = Board(5)
print(b.board)
b.agglompartition(15, b.kullback_leibler_divergence)
# Out:
# [[66 67 68 69 70]
#  [71 72 73 74 75]
#  [76 77 78 79 80]
#  [81 82 83 84 85]
#  [86 87 88 89 90]]
# Clusters:
# Amount of units: 4, average cluster information: Group id: 93, black: 27%, white: 33%, latino: 37%, latino salary: 65%, black salary: 61%, white salary: 66%, pets: 50%, children: 61% population: 29074
# Standard deviation: {'white': 5.802298395176403, 'latino': 10.739335795724674, 'black': 13.076696830622021, 'white_salary': 11.51810169544733, 'latino_salary': 15.588457268119896, 'black_salary': 11.757976016304847, 'children': 27.60434748368452, 'pets': 24.569628948493843}
# District data: District id: 67, black: 31%, white: 25%, latino: 44%, latino salary: 92%, black salary: 51%, white salary: 53%, pets: 85%, children: 66% population: 3989
# District data: District id: 73, black: 19%, white: 38%, latino: 43%, latino salary: 56%, black salary: 78%, white salary: 58%, pets: 59%, children: 29% population: 7575
# District data: District id: 71, black: 46%, white: 31%, latino: 23%, latino salary: 65%, black salary: 56%, white salary: 78%, pets: 57%, children: 96% population: 8465
# District data: District id: 74, black: 18%, white: 36%, latino: 46%, latino salary: 65%, black salary: 60%, white salary: 71%, pets: 25%, children: 57% population: 9045
#
#
# Amount of units: 2, average cluster information: Group id: 96, black: 9%, white: 4%, latino: 86%, latino salary: 75%, black salary: 67%, white salary: 83%, pets: 67%, children: 38% population: 4553
# Standard deviation: {'white': 2.8284271247461903, 'latino': 14.142135623730951, 'black': 11.313708498984761, 'white_salary': 24.748737341529164, 'latino_salary': 27.577164466275352, 'black_salary': 12.727922061357855, 'children': 3.5355339059327378, 'pets': 6.363961030678928}
# District data: District id: 68, black: 0%, white: 2%, latino: 98%, latino salary: 98%, black salary: 78%, white salary: 63%, pets: 62%, children: 41% population: 1888
# District data: District id: 69, black: 16%, white: 6%, latino: 78%, latino salary: 59%, black salary: 60%, white salary: 98%, pets: 71%, children: 36% population: 2665
#
#
# Amount of units: 2, average cluster information: Group id: 92, black: 3%, white: 37%, latino: 59%, latino salary: 62%, black salary: 78%, white salary: 62%, pets: 67%, children: 32% population: 11605
# Standard deviation: {'white': 19.79898987322333, 'latino': 22.627416997969522, 'black': 2.8284271247461903, 'white_salary': 16.97056274847714, 'latino_salary': 12.020815280171307, 'black_salary': 11.313708498984761, 'children': 6.363961030678928, 'pets': 33.94112549695428}
# District data: District id: 81, black: 5%, white: 49%, latino: 46%, latino salary: 55%, black salary: 85%, white salary: 73%, pets: 88%, children: 36% population: 6731
# District data: District id: 77, black: 1%, white: 21%, latino: 78%, latino salary: 72%, black salary: 69%, white salary: 49%, pets: 40%, children: 27% population: 4874
#
#
# Amount of units: 5, average cluster information: Group id: 95, black: 58%, white: 20%, latino: 17%, latino salary: 62%, black salary: 73%, white salary: 69%, pets: 41%, children: 32% population: 27220
# Standard deviation: {'white': 10.526157893552615, 'latino': 14.956603892595405, 'black': 17.23948955160796, 'white_salary': 14.370107863199914, 'latino_salary': 10.014988766843425, 'black_salary': 13.765899897936205, 'children': 24.853571171966415, 'pets': 29.02240513809977}
# District data: District id: 87, black: 48%, white: 13%, latino: 39%, latino salary: 73%, black salary: 58%, white salary: 53%, pets: 88%, children: 68% population: 1546
# District data: District id: 83, black: 37%, white: 31%, latino: 32%, latino salary: 49%, black salary: 85%, white salary: 63%, pets: 62%, children: 23% population: 8600
# District data: District id: 86, black: 62%, white: 32%, latino: 6%, latino salary: 65%, black salary: 88%, white salary: 74%, pets: 47%, children: 70% population: 3913
# District data: District id: 79, black: 76%, white: 17%, latino: 7%, latino salary: 66%, black salary: 68%, white salary: 91%, pets: 47%, children: 23% population: 5442
# District data: District id: 80, black: 76%, white: 9%, latino: 15%, latino salary: 74%, black salary: 61%, white salary: 64%, pets: 8%, children: 25% population: 7719
#
#
# Amount of units: 2, average cluster information: Group id: 91, black: 38%, white: 55%, latino: 6%, latino salary: 85%, black salary: 66%, white salary: 67%, pets: 45%, children: 12% population: 9168
# Standard deviation: {'white': 48.08326112068523, 'latino': 7.7781745930520225, 'black': 40.30508652763321, 'white_salary': 27.577164466275352, 'latino_salary': 12.727922061357855, 'black_salary': 16.97056274847714, 'children': 38.890872965260115, 'pets': 20.506096654409877}
# District data: District id: 89, black: 85%, white: 0%, latino: 15%, latino salary: 71%, black salary: 86%, white salary: 99%, pets: 69%, children: 57% population: 1667
# District data: District id: 84, black: 28%, white: 68%, latino: 4%, latino salary: 89%, black salary: 62%, white salary: 60%, pets: 40%, children: 2% population: 7501
#
#
# Single districts:
# District data: District id: 66, black: 77%, white: 2%, latino: 21%, latino salary: 77%, black salary: 76%, white salary: 93%, pets: 69%, children: 48% population: 7504
# District data: District id: 70, black: 15%, white: 4%, latino: 81%, latino salary: 61%, black salary: 89%, white salary: 73%, pets: 42%, children: 96% population: 5997
# District data: District id: 72, black: 35%, white: 41%, latino: 24%, latino salary: 87%, black salary: 72%, white salary: 81%, pets: 40%, children: 7% population: 8887
# District data: District id: 75, black: 36%, white: 20%, latino: 44%, latino salary: 97%, black salary: 54%, white salary: 81%, pets: 2%, children: 36% population: 6517
# District data: District id: 76, black: 32%, white: 35%, latino: 33%, latino salary: 60%, black salary: 70%, white salary: 67%, pets: 78%, children: 17% population: 4602
# District data: District id: 78, black: 8%, white: 18%, latino: 74%, latino salary: 89%, black salary: 85%, white salary: 75%, pets: 30%, children: 19% population: 2451
# District data: District id: 82, black: 63%, white: 4%, latino: 33%, latino salary: 95%, black salary: 78%, white salary: 94%, pets: 47%, children: 21% population: 8280
# District data: District id: 85, black: 0%, white: 15%, latino: 85%, latino salary: 75%, black salary: 59%, white salary: 62%, pets: 49%, children: 5% population: 6672
# District data: District id: 88, black: 21%, white: 6%, latino: 73%, latino salary: 68%, black salary: 68%, white salary: 75%, pets: 68%, children: 12% population: 8715
# District data: District id: 90, black: 6%, white: 62%, latino: 32%, latino salary: 76%, black salary: 98%, white salary: 96%, pets: 27%, children: 19% population: 8451
# None
# [[66 93 96 96 70]
#  [93 72 93 93 75]
#  [76 92 78 95 95]
#  [92 82 95 91 85]
#  [95 95 88 91 90]]
# /var/folders/p2/g0t6vpx177bc5x1vm0_w_7100000gn/T/ipykernel_2933/3445273678.py:94: RuntimeWarning: divide by zero encountered in log2
#   result += pd[characteristic] * np.log2(pd[characteristic]/qd[characteristic])
# /var/folders/p2/g0t6vpx177bc5x1vm0_w_7100000gn/T/ipykernel_2933/3445273678.py:94: RuntimeWarning: invalid value encountered in double_scalars
#   result += pd[characteristic] * np.log2(pd[characteristic]/qd[characteristic])
