# %%
from district import District
from city import City
from schelling import Schelling
from visualization import Visualization

# %%
district = District()
district.extract_populations()
district.rases
# Out:
# ['white', 'black']

# %%
city = City(district, size=80, agents_ratio=0.6)
city.set_params()

schelling = Schelling(city, district, a=4, n_steps=8000)

visualization = Visualization(schelling)
visualization.show_results()
# Out:
# step: 0, mean si: 1.374167776298269
# step: 100, mean si: 1.35554793828251
# step: 200, mean si: 1.3600461960062096
# step: 300, mean si: 1.3741928443876235
# step: 400, mean si: 1.3796301523156158
# step: 500, mean si: 1.3858514661755053
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 7
#       4 schelling = Schelling(city, district, a=4, n_steps=8000)
#       6 visualization = Visualization(schelling)
# ----> 7 visualization.show_results()
#
# File c:\Users\olasz\Documents\me\informatyka systemów złożonych\Spatial-segregation1\visualization.py:23, in Visualization.show_results(self)
#      20 ax0.imshow(self.initial_board, cmap = self.cmap)
#      21 ax0.set_title(f'INITIAL STATE:  alfa={self.algorithm.a}, p={self.agents_ratio}')
# ---> 23 segregated_city = self.algorithm.run()
#      24 ax1 = fig.add_subplot(spec[0:3, 4:12])
#      25 im = ax1.imshow(segregated_city, cmap = self.cmap)
#
# File c:\Users\olasz\Documents\me\informatyka systemów złożonych\Spatial-segregation1\schelling.py:86, in Schelling.run(self)
#      82 self.si.append(n_similar)
#      83 if n_similar < self.a and n_similar_rase < self.a_rase and n_similar_salary < self.a_salary:
#      84     empty_houses = list(
#      85         zip(
# ---> 86             np.where(neighborhood == -1)[0], np.where(neighborhood == -1)[1]
#      87         )
#      88     )
#      89     if len(empty_houses) != 0:
#      90         new_row, new_col = self.choose_new_position(empty_houses, row, col, n)
#
# File <__array_function__ internals>:4, in where(*args, **kwargs)
#
# File c:\Users\olasz\.conda\envs\visearch\lib\site-packages\numpy\core\multiarray.py:341, in where(condition, x, y)
#     251     """
#     252     inner(a, b)
#     253
#    (...)
#     336
#     337     """
#     338     return (a, b)
# --> 341 @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
#     342 def where(condition, x=None, y=None):
#     343     """
#     344     where(condition, [x, y])
#     345
#    (...)
#     411            [ 0,  3, -1]])
#     412     """
#     413     return (condition, x, y)
#
# KeyboardInterrupt:
